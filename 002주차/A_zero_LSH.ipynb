# %%
k =int (input())
num_list = []
for i in range(0,k,1):
  a= int(input())
  if a!=0:
    num_list.append(a)
  else:
    num_list.pop()

print(sum(num_list))
# Out:
# 10
# 1
# 3
# 5
# 4
# 0
# 0
# 7
# 0
# 0
# 6
# 7
